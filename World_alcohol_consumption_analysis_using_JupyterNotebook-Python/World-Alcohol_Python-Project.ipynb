# %% [markdown]
# # PROJECT

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Load world alcohol consumption data set

# %%
df = pd.read_csv('G:/AVD/Python/datasets/world_alcohol_comsumption.csv')
df
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %% [markdown]
# ### 2. Write a Python program to find out the alcohol consumption details in the year '1987' or '1989' from the dataset.

# %%
df[(df.Year==1987) | (df.Year==1989)]
df
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %% [markdown]
# ### 3. Find out and display horizontal bar chart of the alcohol consumption details in the year '1987' where WHO region is 'Western Pacific' and country is 'Vietnam'

# %%
res= df[df['Year']==1987].where( (df['WHO region']=='Western Pacific') & (df['Country']=='Viet Nam'))
res1=res.dropna()
res1
# Out:
#       Year       WHO region   Country Beverage Types  Display Value
# 28  1987.0  Western Pacific  Viet Nam           Beer           0.11
# 56  1987.0  Western Pacific  Viet Nam           Wine           0.00

# %% [markdown]
# ### 4. Display horizontal bar chart for the year 1987

# %%
import matplotlib.pyplot as plt
plt.barh('Beverage Types', 'Display Value', data=res1, label="1987", color='red')
plt.xlabel("ALCOHOL CONSUMPTION")
plt.ylabel("WESTERN PACIFIC - VIET NAM")
plt.legend()
plt.show()

# %% [markdown]
# ### 5. Write a Pandas program to find and display bar chart to out the alcohol consumption details in the year '1986' or '1989' where WHO region is 'Americas' or 'Europe' from the world alcohol consumption dataset. Use Different colors for each bar.

# %%
# the alcohol consumption in '1986' or '1989' where WHO region is 'Americas' or 'Europe'
result = df[(df['Year']==1986) | (df['Year']==1989)].where((df['WHO region']=='Americas')
| (df['WHO region']=='Europe'))
result
# Out:
#       Year WHO region                           Country Beverage Types  \
# 0      NaN        NaN                               NaN            NaN
# 1   1986.0   Americas                           Uruguay          Other
# 3   1986.0   Americas                          Colombia           Beer
# 8   1986.0   Americas               Antigua and Barbuda        Spirits
# 11  1989.0   Americas                         Guatemala           Beer
# 17     NaN        NaN                               NaN            NaN
# 20     NaN        NaN                               NaN            NaN
# 21  1989.0   Americas                        Costa Rica        Spirits
# 29  1986.0     Europe                             Italy          Other
# 30     NaN        NaN                               NaN            NaN
# 31     NaN        NaN                               NaN            NaN
# 32     NaN        NaN                               NaN            NaN
# ...

# %%
# eliminate the rows with NaN values
result = result.dropna()
result
# Out:
#       Year WHO region                           Country Beverage Types  \
# 1   1986.0   Americas                           Uruguay          Other
# 3   1986.0   Americas                          Colombia           Beer
# 8   1986.0   Americas               Antigua and Barbuda        Spirits
# 11  1989.0   Americas                         Guatemala           Beer
# 21  1989.0   Americas                        Costa Rica        Spirits
# 34  1986.0     Europe                Russian Federation           Wine
# 37  1986.0     Europe                            Sweden           Beer
# 41  1986.0     Europe                    Czech Republic           Beer
# 47  1986.0   Americas                            Mexico          Other
# 49  1986.0     Europe                             Malta           Wine
# 55  1989.0   Americas                          Suriname           Wine
# 57  1989.0     Europe                           Croatia           Wine
# ...

# %%
# select data for the year 1986
result1 = result[result['Year']== 1986]
result1
# Out:
#       Year WHO region                           Country Beverage Types  \
# 1   1986.0   Americas                           Uruguay          Other
# 3   1986.0   Americas                          Colombia           Beer
# 8   1986.0   Americas               Antigua and Barbuda        Spirits
# 34  1986.0     Europe                Russian Federation           Wine
# 37  1986.0     Europe                            Sweden           Beer
# 41  1986.0     Europe                    Czech Republic           Beer
# 47  1986.0   Americas                            Mexico          Other
# 49  1986.0     Europe                             Malta           Wine
# 74  1986.0   Americas  Bolivia (Plurinational State of)        Spirits
# 86  1986.0   Americas                           Bahamas           Wine
#
#     Display Value
# 1            0.50
# 3            4.27
# 8            1.55
# 34           0.80
# 37           3.04
# 41           6.82
# 47           0.04
# 49           1.49
# ...

# %%
# select data for the year 1989
result2 = result[result['Year']== 1989]
result2
# Out:
#       Year WHO region                           Country Beverage Types  \
# 11  1989.0   Americas                         Guatemala           Beer
# 21  1989.0   Americas                        Costa Rica        Spirits
# 55  1989.0   Americas                          Suriname           Wine
# 57  1989.0     Europe                           Croatia           Wine
# 64  1989.0   Americas  Bolivia (Plurinational State of)           Beer
# 78  1989.0   Americas                           Jamaica          Other
# 79  1989.0     Europe                           Finland          Other
# 91  1989.0     Europe                          Bulgaria           Beer
#
#     Display Value
# 11           0.62
# 21           4.51
# 55           0.04
# 57           5.10
# 64           1.26
# 78           0.00
# 79           2.09
# 91           4.43

# %%
# display bar charts for the years 1986 and 1989
import matplotlib.pyplot as plt
plt.bar('WHO region', 'Display Value', data=result1, label="1986", color='orange')
plt.xlabel("WHO REGION")
plt.ylabel("ALCOHOL CONSUMPTION")
plt.legend()
plt.show()

# %%
plt.bar('WHO region', 'Display Value', data=result2, label="1989", color='cyan')
plt.xlabel("WHO REGION")
plt.ylabel("ALCOHOL CONSUMPTION")
plt.legend()
plt.show()

# %% [markdown]
# ### 6. Write a Pandas program to find out the 'WHO region, 'Country', 'Beverage Types' in the year '1986' or '1989' where WHO region is 'Americas' or 'Europe' from the world alcohol consumption dataset

# %%
result = df[(df['Year']==1986) | (df['Year']==1989)].where((df['WHO region']=='Americas')
| (df['WHO region']=='Europe'))[['WHO region', 'Country', 'Beverage Types']]
result
# Out:
#    WHO region                           Country Beverage Types
# 0         NaN                               NaN            NaN
# 1    Americas                           Uruguay          Other
# 3    Americas                          Colombia           Beer
# 8    Americas               Antigua and Barbuda        Spirits
# 11   Americas                         Guatemala           Beer
# 17        NaN                               NaN            NaN
# 20        NaN                               NaN            NaN
# 21   Americas                        Costa Rica        Spirits
# 29     Europe                             Italy          Other
# 30        NaN                               NaN            NaN
# 31        NaN                               NaN            NaN
# 32        NaN                               NaN            NaN
# 34     Europe                Russian Federation           Wine
# 37     Europe                            Sweden           Beer
# ...

# %% [markdown]
# ### 7. Write a Pandas program to find out the records where consumption of beverages per person average >=5 and Beverage Types is Beer from world alcohol consumption dataset.

# %%
result = df[(df['Display Value']>=5) & (df['Beverage Types']=='Beer')]
result
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 41  1986     Europe  Czech Republic           Beer           6.82

# %% [markdown]
# ### 8. Write a Pandas program to find out and display Pie chart of the records where consumption of beverages per person average >=4 and Beverage Types is Beer, Wine,Spirits from world alcohol consumption dataset.

# %%
result1 = df[(df['Display Value']>=4) & (df['Beverage Types']=='Beer')]['Display Value']
result2 = df[(df['Display Value']>=4) & (df['Beverage Types']=='Wine')]['Display Value']
result3 = df[(df['Display Value']>=4) & (df['Beverage Types']=='Spirits')]['Display Value']
#print(result1 ,result2,result3)

#draw pie charts
plt.pie(result1, shadow=True, autopct='%.1f%%')
plt.show()
plt.pie(result2, shadow=True, autopct='%.1f%%')
plt.show()
plt.pie(result3, shadow=True, autopct='%.1f%%')
plt.show()

# %% [markdown]
# ### 9. Write a Pandas program to filter the WHO region and Beverage Types columns and records by range from 0 to 15 from dataset

# %%
result = df.loc[:15, ['WHO region', 'Beverage Types']]
result
# Out:
#                WHO region Beverage Types
# 0         Western Pacific           Wine
# 1                Americas          Other
# 2                  Africa           Wine
# 3                Americas           Beer
# 4                Americas           Beer
# 5                Americas          Other
# 6                  Africa           Wine
# 7                  Africa        Spirits
# 8                Americas        Spirits
# 9                  Africa          Other
# 10                 Africa           Wine
# 11               Americas           Beer
# 12        Western Pacific           Beer
# 13  Eastern Mediterranean          Other
# 14        Western Pacific        Spirits
# 15                 Africa           Wine

# %% [markdown]
# ### 10. Write a Pandas program to filter those records where WHO region contains "Ea" substring from dataset and show count of it

# %%
result = df['WHO region']
result = df[result.str.contains('Ea')]
result
# Out:
#     Year             WHO region                                Country  \
# 13  1984  Eastern Mediterranean                            Afghanistan
# 20  1986        South-East Asia                                Myanmar
# 25  1984  Eastern Mediterranean                                Tunisia
# 27  1984  Eastern Mediterranean                                Bahrain
# 36  1987  Eastern Mediterranean                                  Egypt
# 38  1987  Eastern Mediterranean                                  Qatar
# 52  1986  Eastern Mediterranean                           Saudi Arabia
# 53  1984  Eastern Mediterranean                                 Kuwait
# 58  1984  Eastern Mediterranean                                Somalia
# 59  1989  Eastern Mediterranean                   Syrian Arab Republic
# 60  1987  Eastern Mediterranean             Iran (Islamic Republic of)
# 63  1985  Eastern Mediterranean                                  Libya
# ...

# %%
n = len(result)
n # count the no. of such records -> 22
# Out:
# 22

# %% [markdown]
# ### 11. Write a Pandas program to filter those records where WHO region matches with multiple values (Africa, Eastern Mediterranean, Europe) from dataset

# %%
# first replace the WHO region column name as WHO_region
df1 = df.rename(columns={'WHO region': 'WHO_region'})
df1
# Out:
#     Year       WHO_region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %%
# now apply query() method
result = df1.query("WHO_region in ['Africa', 'Eastern Mediterranean', 'Europe']")
result
# Out:
#     Year WHO_region            Country Beverage Types  Display Value
# 2   1985     Africa       Cte d'Ivoire           Wine           1.62
# 6   1987     Africa          Mauritius           Wine           0.13
# 7   1985     Africa             Angola        Spirits           0.39
# 9   1984     Africa            Nigeria          Other           6.10
# 10  1987     Africa           Botswana           Wine           0.20
# ..   ...        ...                ...            ...            ...
# 93  1987     Africa         Madagascar          Other            NaN
# 94  1985     Europe            Ukraine        Spirits           3.06
# 95  1984     Africa              Niger          Other           0.00
# 96  1985     Europe         Luxembourg           Wine           7.38
# 98  1984     Africa  Equatorial Guinea           Wine           0.00
#
# [69 rows x 5 columns]

# %% [markdown]
# ### 12. Write a Pandas program to filter those records which not appears in a given list from dataset.
# who_region = ["Africa", "Eastern Mediterranean", "Europe"]

# %%
result = df1.query("WHO_region not in ['Africa', 'Eastern Mediterranean', 'Europe']")
result
# Out:
#     Year       WHO_region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# 5   1987         Americas                              Guatemala
# 8   1986         Americas                    Antigua and Barbuda
# 11  1989         Americas                              Guatemala
# 12  1985  Western Pacific       Lao People's Democratic Republic
# 14  1985  Western Pacific                               Viet Nam
# 16  1984         Americas                             Costa Rica
# 20  1986  South-East Asia                                Myanmar
# 21  1989         Americas                             Costa Rica
# 28  1987  Western Pacific                               Viet Nam
# ...

# %% [markdown]
# ### 13. Write a Pandas program to find average consumption of wine per person greater than 2 in world alcohol consumption dataset.

# %%
result = df[df["Beverage Types"] == 'Wine'][df['Display Value']>2]
result
# Out:
# C:\Users\RATNESH\AppData\Local\Temp\ipykernel_5912\4147393221.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = df[df["Beverage Types"] == 'Wine'][df['Display Value']>2]
#     Year WHO region      Country Beverage Types  Display Value
# 57  1989     Europe      Croatia           Wine           5.10
# 81  1985     Europe  Netherlands           Wine           2.54
# 96  1985     Europe   Luxembourg           Wine           7.38

# %%
#Another solution:
result = df[(df['Beverage Types'] == 'Wine') & (df['Display Value'] > 2)]
result
# Out:
#     Year WHO region      Country Beverage Types  Display Value
# 57  1989     Europe      Croatia           Wine           5.10
# 81  1985     Europe  Netherlands           Wine           2.54
# 96  1985     Europe   Luxembourg           Wine           7.38

# %% [markdown]
# ### 14. Write a Pandas program to filter rows, based on row numbers ended with 0, like 0, 10, 20, 30 from dataset.

# %%
# first create a list of row numbers
lst = list(range(0, 100, 10))
# then retrieve only those rows using iloc[]
rows = df.iloc[lst, :]
rows
# Out:
#     Year             WHO region                     Country Beverage Types  \
# 0   1986        Western Pacific                    Viet Nam           Wine
# 10  1987                 Africa                    Botswana           Wine
# 20  1986        South-East Asia                     Myanmar           Wine
# 30  1986                 Africa                Sierra Leone          Other
# 40  1987                 Europe                     Austria        Spirits
# 50  1985                 Europe                 Switzerland          Other
# 60  1987  Eastern Mediterranean  Iran (Islamic Republic of)          Other
# 70  1986                 Africa                  Madagascar        Spirits
# 80  1985                 Africa                      Malawi          Other
# 90  1989                 Africa                      Malawi           Wine
#
#     Display Value
# 0            0.00
# 10           0.20
# 20           0.00
# 30           4.48
# 40           1.90
# 50           0.30
# ...

# %% [markdown]
# ### 15. Write a Pandas program to also select rows with Index label 0 to 9 with some columns from dataset.

# %%
# first create a list of row numbers
lst = list(range(0, 10))
# then retrieve only those rows using iloc[] and from some columns
rows = df.loc[lst, ['Year', 'Country']] # same as: df.iloc[lst, [0,2]]
rows
# Out:
#    Year                Country
# 0  1986               Viet Nam
# 1  1986                Uruguay
# 2  1985           Cte d'Ivoire
# 3  1986               Colombia
# 4  1987  Saint Kitts and Nevis
# 5  1987              Guatemala
# 6  1987              Mauritius
# 7  1985                 Angola
# 8  1986    Antigua and Barbuda
# 9  1984                Nigeria

# %% [markdown]
# ### 16. Write a Pandas program to filter all columns where all entries present, check which rows and columns has a NaN and finally drop rows with any NaNs from world alcohol consumption dataset.

# %%
# find out total no. of NaN values in each column.
df.isnull().sum()
df.dropna(inplace=True) # drop the rows with NaN values
df
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %% [markdown]
# ### 17. Write a Pandas program to filter all records starting from the 'Year' column, access every other column from world alcohol consumption dataset.

# %%
# first know the total no. of columns as len(df.columns).
# create range object with alternate column numbers 0, 2, 4 till the total no. of columns.
obj = range(0, len(df.columns), 2)
lst = list(obj) # convert range object into a list
df.iloc[:, lst]
# Out:
#     Year                                Country  Display Value
# 0   1986                               Viet Nam           0.00
# 1   1986                                Uruguay           0.50
# 2   1985                           Cte d'Ivoire           1.62
# 3   1986                               Colombia           4.27
# 4   1987                  Saint Kitts and Nevis           1.98
# ..   ...                                    ...            ...
# 95  1984                                  Niger           0.00
# 96  1985                             Luxembourg           7.38
# 97  1984                              Indonesia           0.00
# 98  1984                      Equatorial Guinea           0.00
# 99  1985  Democratic People's Republic of Korea           0.00
#
# [95 rows x 3 columns]

# %% [markdown]
# ### 18. Write a Pandas program to filter all records starting from the 2nd row, access every 5th row from dataset

# %%
# first know the total no. of rows as len(df).
# create range object with alternate row numbers 2, 7, 12,... till the total no. of rows.
obj = range(2, len(df), 5)
lst = list(obj) # convert range object into a list
df.iloc[lst, :]
# Out:
#     Year             WHO region                           Country  \
# 2   1985                 Africa                      Cte d'Ivoire
# 7   1985                 Africa                            Angola
# 12  1985        Western Pacific  Lao People's Democratic Republic
# 17  1989                 Africa                        Seychelles
# 22  1984                 Europe                           Romania
# 28  1987        Western Pacific                          Viet Nam
# 34  1986                 Europe                Russian Federation
# 39  1987                 Africa                      Burkina Faso
# 45  1989                 Africa                          Zimbabwe
# 50  1985                 Europe                       Switzerland
# 55  1989               Americas                          Suriname
# 60  1987  Eastern Mediterranean        Iran (Islamic Republic of)
# 65  1989  Eastern Mediterranean                           Somalia
# ...

# %% [markdown]
# ### 19. Write a Pandas program to rename all and only some of the column names from dataset by adding _ in column names.

# %%
df1 = df.rename(columns={'Year': '_Year', 'WHO region': '_WHO_region',
'Country': '_Country', 'Beverage Types': '_Beverage_Types', 'Display Value': '_Display_Value'})
df1
# Out:
#     _Year      _WHO_region                               _Country  \
# 0    1986  Western Pacific                               Viet Nam
# 1    1986         Americas                                Uruguay
# 2    1985           Africa                           Cte d'Ivoire
# 3    1986         Americas                               Colombia
# 4    1987         Americas                  Saint Kitts and Nevis
# ..    ...              ...                                    ...
# 95   1984           Africa                                  Niger
# 96   1985           Europe                             Luxembourg
# 97   1984  South-East Asia                              Indonesia
# 98   1984           Africa                      Equatorial Guinea
# 99   1985  South-East Asia  Democratic People's Republic of Korea
#
#    _Beverage_Types  _Display_Value
# 0             Wine            0.00
# 1            Other            0.50
# 2             Wine            1.62
# ...
